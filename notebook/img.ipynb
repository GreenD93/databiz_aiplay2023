# %%
import glob
from PIL import Image


img_paths = glob.glob('data/imgs/*.jpeg')

for img_path in img_paths:
    img = Image.open(img_path)

    area = (0,50,750,1334)
    cropped_img = img.crop(area)

    img_nm = img_path.split('/')[-1]
    save_path = f"data/cropped_imgs/{img_nm}"
    cropped_img.save(save_path)

# %%
img_path = 'IMG_4555.PNG'
img = Image.open(img_path)

area = (0,50,750,1334)
cropped_img = img.crop(area)

img_nm = img_path.split('/')[-1]
save_path = f"data/cropped_imgs/homelearn_event.jpeg"
cropped_img.save(save_path)

# %%
img_path.split('/')[-1]
# Out:
# '21.플러스체크카드.jpeg'

# %%
img = Image.open(img_paths[0])

area = (0,120,750,1334)
img.crop(area)
# Out:
# <PIL.Image.Image image mode=RGB size=750x1214>

# %%
for img_path in img_paths:
    
    img = Image.open(img_path)
    
    area = (0,120,750,1334)
    cropped_img = img.crop(area)

    img_nm = img_path.split('/')[-1]
    new_img_path = f"data/cropped_imgs/{img_nm}"
    cropped_img.save(new_img_path)
